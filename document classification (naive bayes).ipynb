# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

news_data = pd.read_csv("C:\\Users\\PC\\Desktop\\Python\\Dataset\\uci-news-aggregator.csv")

# %% [markdown]
# b-business
# t-technology & science
# e-enterntainment
# m-health

# %%
import string

news_data['CATEGORY'] = news_data.CATEGORY.map({ 'b': 1, 't': 2, 'e': 3, 'm': 4 })
news_data['TITLE'] = news_data.TITLE.map(
   lambda x: x.lower().translate(str.maketrans('','', string.punctuation))
)

news_data.head()
# Out:
#    ID                                              TITLE  \
# 0   1  fed official says weak data caused by weather ...
# 1   2  feds charles plosser sees high bar for change ...
# 2   3  us open stocks fall after fed official hints a...
# 3   4  fed risks falling behind the curve charles plo...
# 4   5   feds plosser nasty weather has curbed job growth
#
#                                                  URL          PUBLISHER  \
# 0  http://www.latimes.com/business/money/la-fi-mo...  Los Angeles Times
# 1  http://www.livemint.com/Politics/H2EvwJSK2VE6O...           Livemint
# 2  http://www.ifamagazine.com/news/us-open-stocks...       IFA Magazine
# 3  http://www.ifamagazine.com/news/fed-risks-fall...       IFA Magazine
# 4  http://www.moneynews.com/Economy/federal-reser...          Moneynews
#
#    CATEGORY                          STORY             HOSTNAME      TIMESTAMP
# 0         1  ddUyU0VZz0BRneMioxUPQVP6sIxvM      www.latimes.com  1394470370698
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    news_data['TITLE'],
    news_data['CATEGORY'],
    random_state = 1
)

print("Training dataset: ", X_train.shape[0])
print("Test dataset: ", X_test.shape[0])
# Out:
# Training dataset:  316814
# Test dataset:  105605

# %%
from sklearn.feature_extraction.text import CountVectorizer

count_vector = CountVectorizer(stop_words = 'english')
training_data = count_vector.fit_transform(X_train)
testing_data = count_vector.transform(X_test)

# %%
from sklearn.naive_bayes import MultinomialNB

naive_bayes = MultinomialNB()
naive_bayes.fit(training_data, y_train)
# Out:
# MultinomialNB()

# %%
predictions = naive_bayes.predict(testing_data)
predictions
# Out:
# array([1, 1, 3, ..., 1, 1, 4], dtype=int64)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

print("Accuracy score: ", accuracy_score(y_test, predictions))
print("Recall score: ", recall_score(y_test, predictions, average = 'weighted'))
print("Precision score: ", precision_score(y_test, predictions, average = 'weighted'))
print("F1 score: ", f1_score(y_test, predictions, average = 'weighted'))
# Out:
# Accuracy score:  0.9283367264807537
# Recall score:  0.9283367264807537
# Precision score:  0.9284057938650963
# F1 score:  0.9283611479662868

# %%
newsTitle = ['Phoenix boy undergoes surgery to repair throat damage - WFSB 3 Connecticut']
newsTitle_transformed = count_vector.transform(newsTitle)
prediction = naive_bayes.predict(newsTitle_transformed)
print(prediction)
# Out:
# [4]
